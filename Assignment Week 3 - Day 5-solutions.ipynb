# %% [markdown]
# # **MATH**

# %% [markdown]
# ## 1. Suppose the number of customers arriving at a store obeys a Poisson distribution with an average of λ customers per unit time. That is, if Y is the number of customers arriving in an interval of length t, then Y∼Poisson(λt). Suppose that the store opens at time t=0. Let X be the arrival time of the first customer. Show that X∼Exponential(λ).

# %% [markdown]
# ![week 3_3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2. Let X be a random variable with PDF given by
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![week 3_8.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 3. Let X and Y be jointly continuous random variables with joint PDF
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Week 3_6.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![week 3_7.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 4. Let X and Y be two independent discrete random variables with the same CDFs FX and FY .
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![week 3_4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **MACHINE LEARNING**

# %% [markdown]
# ## 1. a. What are the ways to avoid the problem of initialization sensitivity in the K means Algorithm?
#
# ## b. How to decide the optimal number of K in the K means Algorithm?

# %% [markdown]
# **a:**<br>
# **There are two ways to avoid the problem of initialization sensitivity int the K Means Algorithm:**<br>
# * **Repeat K means:**
#   * Repeat K Means is similar to K Means , but it can repeats the algorithm again and again along with initializing the centroids followed by picking the cluster which results in the small intracluster(with in the cluster) distance and large intercluster(between the clusters) distance.
# <br>
#
# * **K Means++:**<br>
#  * K Means++ algorithm is a smart technique for centroid initialization that initialized one centroid while ensuring the others to be far away from the chosen one resulting in faster convergence.<br>
#
#  **The steps to follow for centroid initialization are:**
#        Step-1: Pick the first centroid point randomly.
#        Step-2: Compute the distance of all points in the dataset from the selected centroid.
#                The distance of xi point from the farthest centroid can be calculated by the given formula:
#                   distance calculation = d = max(j:1->m)||xi-ci||^2
#                   where,di: Distance of xi point from the farthest centroid , m: number of centroids already picked .
#        Step-3: Make the point xi as the new centroid that is having maximum probability proportional to di .
#        Step-4: Repeat the above last two steps till you find k centroids.
# Amongst the above two techniques, K-Means++ is the best approach.

# %% [markdown]
# **b:**<br>
#
# The K is a hyperparameter in K Means Algorithm . In order to find the optimal value of k, we need to observe our business problem carefully, along with analyzing the business inputs as well as the person who works on that data so that a decent idea regarding the optimal number of clusters can be extracted.
#
# If we do not get any inference from the data directly we often use the following mentioned techniques:
#
# **Elbow Method :** This method finds the point of inflection on a graph of the
#   percentage of variance explained to the number of K and finds the elbow point .<br>
# **Silhouette method :** The silhouette method calculates similarity/dissimilarity score between their assigned cluster and the next best (i.e, nearest) cluster for each of the data points.

# %% [markdown]
# ## 2. a. What is the Objective Function of k-Means?
#
# ## b. How would you perform k-Means on very large datasets?

# %% [markdown]
# * K means is the unsupervised machine learning algorithm to cluster the data points in the given dataset .
# * The main objective function of the K Means algorithm is When we are clustering the data points using K Means , it always tries to minimize the intra cluster(same group) distance and maximize the inter cluster (different group) distance in given space .
# * **Steps of K Means algorithm :**<br>
#    1. Select the number K to decide the number of clusters.
#    2. Select random K points or centroids. (It can be other from the input dataset).
#    3. Assign each data point to their closest centroid,by calculating the distance(euclidean distance) between each centroid and each data point , which will form the predefined K clusters.
#    4. Calculate the mean of each centroid and update the centroids with its mean.
#    5. Repeat the third steps, which means reassign each datapoint to the new closest centroid of each cluster.
#    6. Repeat the above steps untill , there no difference between previous and current centroids .
#    7. The model is ready.

# %% [markdown]
# **b:**<br>
# * To perform K-Means on very large datasets , I can choose mini-batch K Means .
# Because , It takes the random mini-batches of data to update the cluster mean with a decreasing learning rate .
#  * For each batch , the points are first assigned to a cluster and then mean are calcuated again .
#  * The cluster centers are then further calculated  using gradient descent .
#  * This algorithm provides faster convergence than the typical k-means, but with a slightly different cluster output.

# %% [markdown]
# ## 3. a. Explain the different linkage methods used in the Hierarchical Clustering Algorithm.
#
# ## b. List down the pros and cons of complete and single linkages methods in the Hierarchical Clustering Algorithm.

# %% [markdown]
# **a:**
# * The process of Hierarchical Clustering involves either clustering sub-clusters(data points in the first iteration) into larger clusters in a bottom-up manner or dividing a larger cluster into smaller sub-clusters in a top-down manner. In heirarchical clustering , the distance between sub clusters needs to be calculated.
# * The different types of linkages describe the different approaches to measure the distance between two sub-clusters of data points.
# * **The different types of linkages are:**
#
#  1. **Single Linkage:** For two clusters A and B, the single linkage returns the minimum distance between two points i and j such that i belongs to A and j belongs to S.<br>
#                 L(A,B) = min(D(i,j)) ; i 𝛜 A , j 𝛜 B
#  2. **Complete Linkage:** For two clusters R and S, the complete linkage returns the maximum distance between two points i and j such that i belongs to A and j belongs to B.
#                L(A,B) = max(D(i,j)) ; i 𝛜 A , j 𝛜 B
#  3. **Average Linkage:** For two clusters A and B, first for the distance between any data-point i in A and any data-point j in B and then the arithmetic mean of these distances are calculated. Average Linkage returns this value of the arithmetic mean.
#             L(A,B) = (1/(Na+Nb))  ∑ ∑(D(i,j)) ; i 𝛜 A , j 𝛜 B ,
#             where , Na is Number of data-points in A and Nb is Number of data-points in B .

# %% [markdown]
# **b:**<br>
#  * **Pros of Single-linkage:**
#    * This approach can differentiate between non-elliptical shapes as long as the gap between the two clusters is not small.
#  * **Cons of Single-linkage:**
#   * This approach cannot separate clusters properly if there is noise between clusters.
# <br>
#
# * **Pros of Complete-linkage:**
#
#   * This approach gives well-separating clusters if there is some kind of noise present between clusters.
# * **Cons of Complete-Linkage:**
#  * This approach is biased towards globular clusters.
# It tends to break large clusters.

# %% [markdown]
# ## 4. a. What is a dendrogram in Hierarchical Clustering Algorithm?
#
# ## b. Explain the different parts of dendrograms in the Hierarchical Clustering Algorithm.

# %% [markdown]
# **a:**<br>
# * A dendrogram is defined as a tree-like structure that is mainly used to store each step as a memory that the Hierarchical clustering algorithm performs.
# * In the dendrogram plot, the Y-axis represents the Euclidean distances between the observations, and the X-axis represents all the observations present in the given dataset.

# %% [markdown]
# **b:**<br>
# * Dendogram is a tree like structure with specific arrangement of branches . That the branches shows , how they are similar or dissiilar .
# * The branches that are having  or close to the same height are similar to each other .
# * The branches with different heights are dissimilar from each other.That the more the value of the difference in height, the more will be dissimilar.
# * Each branch has one or more leaves.
# * A branch can have an infinite amount of leaves but the more leaves we have, the harder the dendrogram will be to read and understand .
